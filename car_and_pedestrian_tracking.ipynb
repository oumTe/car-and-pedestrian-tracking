# %%
from google.colab.patches import cv2_imshow
from google.colab import files
import cv2
import matplotlib.pyplot as plt

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-49b45344-a4e4-4491-bdfb-6c8c9be142f7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-49b45344-a4e4-4491-bdfb-6c8c9be142f7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cars.png to cars.png

# %%
uploaded=files.upload()
# Out:
#      <input type="file" id="files-e8b87af5-2f72-499b-abe6-433a652d9b95" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8b87af5-2f72-499b-abe6-433a652d9b95">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cars.xml to cars.xml

# %%
car_tracker=cv2.CascadeClassifier('cars.xml')

# %%
#pre-trained data
classifier_file='cars.xml'

# %%
img=cv2.imread('cars.png')
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
grayscaled_img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(grayscaled_img)

# %%
car_coordinates = car_tracker.detectMultiScale(grayscaled_img)
print(car_coordinates)
# Out:
# [[ 12 209 111 111]
#  [160 268 135 135]
#  [ 49 333  68  68]
#  [490 240 350 350]
#  [320 308  76  76]
#  [452 432  34  34]
#  [126 456  48  48]
#  [348 605  72  72]
#  [247 591  87  87]]

# %%
for (x,y,w,h) in car_coordinates:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
    plt.imshow(img)
